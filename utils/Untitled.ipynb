# %%
import numpy as np
import preprocess
import matplotlib.pyplot as plt

# %%
img = plt.imread('../results/kth_bi_lstm_t1s3_rgb/118000/v_ApplyEyeMakeup_g24_c02.avi_1-11/gt1.png')
plt.imshow(img)
H, W, C = img.shape
H
# Out:
# 128

# %%
data = np.ones([1, 11, 128, 128, 3], np.float32)
data[0, 0, :, :, :] = img
data.shape
# Out:
# (1, 11, 128, 128, 3)

# %%
plt.imshow(data[0, 0, :, :, :])

# %%
a = np.reshape(data, [1, 11, int(H/4), 4, int(W/4), 4, C])
b = np.transpose(a, [0,1,2,4,3,5,6])
patch_tensor = np.reshape(b, [1, 11, int(H/4), int(W/4), int(4*4*C)])
patch_tensor.shape
# Out:
# (1, 11, 32, 32, 48)

# %%
plt.figure(figsize=(10, 5))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(patch_tensor[0, 0, :, :, i], cmap='gray')
